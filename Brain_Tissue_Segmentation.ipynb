# %% [markdown]
# <a href="https://colab.research.google.com/github/sara2cb/Information-Processing-in-Medical-Imaging/blob/main/Brain_Tissue_Segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**IPMI20-21 Lab session**
#
# ---
#
#
# #**Brain Tissue Segmentation**
# The goal of the workshop is to segment 2D brain images using a Gaussian Mixture Model, solved using the Expectation-Maximisation algorithm. The code for K-means segmentation is included for comparison. Your task is to use the code below to generate segmentations on the 4 different input images, and use different options when running the segmentation.<br>
# ###Exercise
# **You should use these data to produce brief report that includes tables and/or figures that summarises the different results.**<br>
# Please share your report with one of the teaching team for some feedback prior to leaving the session.
#
# ---
#
#
# Finally, there is an exercise to load a 3D Nifti file, slice into 2D images and then segment using one of the pipelines tested previously.

# %% [markdown]
# #Set up
# Start by importing numpy, scipy, nibabel and the Python Image Library, along with matplotlib and seaborn for plotting purposes.

# %%
from collections import defaultdict
from IPython.display import display, Image # to display images
import matplotlib.pyplot as plt
import nibabel as nib # for reading Nifti files
import numpy as np
import PIL as pl
import os
import scipy as sp
import seaborn as sns
from sklearn import cluster # for running K-means
import sys

# %% [markdown]
# ##Define functions
# Here we will define a few different functions to make running the pipelines more straightforward.

# %% [markdown]
# ###Read images and convert to arrays

# %%
def read_file(filename):
    imagefile = pl.Image.open(filename)
    image_array = np.array(imagefile.getdata(), np.uint8).reshape(imagefile.size[1], imagefile.size[0])
    return image_array.astype('float32')

# %% [markdown]
# ###Convert array to image

# %%
def array_to_image(array):
    minimal_value = np.min(array)
    maximal_value = np.max(array)
    if minimal_value < 0 or maximal_value > 255:
        array = 255*(array-minimal_value)/(maximal_value-minimal_value)
    array_uint8 = array.astype('uint8')
    return pl.Image.fromarray(array_uint8, 'L') #saves as 8-bit pixels

# %% [markdown]
# ###Save array as image file

# %%
def save_file(array,filename):
    imagefile = array_to_image(array)
    imagefile.save(filename)

# %% [markdown]
# ###Markov Random Field
# Function to apply a 2D MRF, hence 4 neighbouring pixels (top, bottom, left, right).

# %%
def Umrf(pik, k):
    G = np.ones((4, 4)) - np.diag([1, 1, 1, 1])
    Umrf = np.ndarray([np.size(pik, 0), np.size(pik, 1)])
    for indexX in range(0, np.size(pik, 0)):
        for indexY in range(0, np.size(pik, 1)):
            UmrfAtIndex = 0
            for j in range(0, np.size(pik, 2)):
                Umrfj=0
                # Umrf top
                if (indexY + 1) < np.size(pik, 1):
                    Umrfj += pik[indexX, indexY + 1, j]
                # Umrf bottom
                if (indexY - 1) > -1:
                    Umrfj += pik[indexX, indexY - 1, j]
                # Umrf right
                if (indexX + 1) < np.size(pik, 0):
                    Umrfj += pik[indexX + 1, indexY, j]
                # Umrf left
                if (indexX - 1) > -1:
                    Umrfj += pik[indexX - 1, indexY, j]
                UmrfAtIndex += Umrfj * G[k, j]
            Umrf[indexX,indexY]=UmrfAtIndex;
    return Umrf

# %% [markdown]
# ##Get data
# ###Clone from Github

# %%
# !git clone https://github.com/james-cole/IPMI-teaching.git
fileLocation = "./IPMI-teaching/"
# !ls -lh IPMI-teaching/
# Out:
# fatal: destination path 'IPMI-teaching' already exists and is not an empty directory.
# total 6.9M
# -rw-r--r-- 1 root root  27K Mar  4 15:10 brain_bias.png
# -rw-r--r-- 1 root root  31K Mar  4 15:10 brain_noise.png
# -rw-r--r-- 1 root root  22K Mar  4 15:10 brain.png
# -rw-r--r-- 1 root root  13K Mar  4 15:10 CSF_prior.png
# -rw-r--r-- 1 root root  25K Mar  4 15:10 GM_prior.png
# -rw-r--r-- 1 root root 6.2K Mar  4 15:10 NonBrain_prior.png
# -rw-r--r-- 1 root root   90 Mar  4 15:10 README.md
# -rw-r--r-- 1 root root 6.7M Mar  4 15:10 T1w_standard.nii.gz
# -rw-r--r-- 1 root root  35K Mar  4 15:10 verynoisy.png
# -rw-r--r-- 1 root root  25K Mar  4 15:10 WM_prior.png

# %% [markdown]
# ##Display brain slice images
# Take a look at the input data. You'll notice the varying quality and the fact that they have been spatially normalised using image registration.

# %%
display(Image(fileLocation+'brain.png'))
display(Image(fileLocation+'brain_bias.png'))
display(Image(fileLocation+'brain_noise.png'))
display(Image(fileLocation+'verynoisy.png'))

# %% [markdown]
# ##Load data
# This reads in a PNG file and converts it to an array.

# %%
print("Loading data")

# Brain slices
brainData = read_file(fileLocation+'brain.png')
noiseData = read_file(fileLocation+'brain_noise.png')
verynoisyData = read_file(fileLocation+'verynoisy.png')
biasData = read_file(fileLocation+'brain_bias.png')
# Out:
# Loading data

# %% [markdown]
# ####Get image dimensions

# %%
brainData.shape
# Out:
# (181, 217)

# %% [markdown]
# ##Plot histograms of the brain images
# Try changing which images are displayed and compare the histograms

# %%
imgData = brainData
plt.figure(figsize=(12,6))
plt.hist(np.concatenate(imgData), bins=100, facecolor='orangered', edgecolor='black')
plt.xlabel('Intensity')
plt.ylabel('Count')
plt.tight_layout()

# %% [markdown]
# ##Density plot of brain slice intensities

# %%
plt.figure(figsize=(12,6))
sns.kdeplot(np.concatenate(brainData), color = 'orangered', shade =True, bw_method=0.1)
plt.tight_layout()

# %% [markdown]
# #K-means for brains
# Here we try using the sci-kit learn implementation of k-means to segment a brain image. **Try changing the number of clusters (k) and see how this impacts the results.**

# %%
imgData = brainData
# set number of clusters K
k = 5
np.random.seed(0)

# Reshape to a (n_sample, n_feature) array
X = imgData.reshape((-1, 1))

# define and run K-means
k_means = cluster.KMeans(n_clusters=k, n_init=4)
k_means.fit(X)
values = k_means.cluster_centers_.squeeze()
labels = k_means.labels_

# create an array from labels and values
imgData_seg = np.choose(labels, values)
imgData_seg.shape = imgData.shape

vmin = imgData.min()
vmax = imgData.max()

# original image
plt.figure(1, figsize=(7,6))
plt.imshow(imgData, cmap='gray', vmin=vmin, vmax=256)

# segmented image
plt.figure(2, figsize=(7, 6))
plt.imshow(imgData_seg, cmap='gist_rainbow', vmin=vmin, vmax=vmax)

# %% [markdown]
# ##Plot the different classes
# While it's useful to view the predicted classes together, it can also help to see them plotted separately. Do the maps resemble known brain tissue distributions?

# %%
fig,axes = plt.subplots(nrows=k,ncols=1, figsize=(k*5,k*5))
axes = axes.flatten()
seg = defaultdict()
for i in range(k):
  seg[i] = np.ma.masked_where(imgData_seg == values[i], imgData_seg)
  axes[i].imshow(seg[i], cmap='binary', vmin=0, vmax=1)
print("Number of clusters K = "+ str(k))
plt.tight_layout()
# Out:
# Number of clusters K = 5

# %% [markdown]
# #Expectation-maximisation for GMM segmentation
# A potentially more powerful approach is to fit a Gaussian Mixture Model (GMM) instead, that takes into the parameters of the latent distributions in the data.
# ##Select data and set parameters
# Choose which image to use as input (normal brain, noisy, very nosiy or bias).<br>
# Set the number of classes, allocate space for arrays and for the priors, the maximum number of iterations and convergence tolerance level.<br>
# You can try varying the maximum number of iterations (*maxIterations*) or tolerance level and see how this affects results.

# %%
# Select input data
imgData = brainData

# Parameters
didNotConverge = 1
iteration = 0
maxIterations = 200
numClass = 5
beta = 2
logLik = int(-10e8)
oldLogLik = int(-10e8)
tolerance = 200

# Initialise mean and variances
np.random.seed(37) # set seed for reproducibility
mean = np.random.rand(numClass,1)*256;
var = (np.random.rand(numClass,1)*10)+200;

# Allocate space for the posteriors
classProb = np.ndarray([np.size(imgData,0),np.size(imgData,1),numClass])
classProbSum = np.ndarray([np.size(imgData,0),np.size(imgData,1)])

# Define array for MRF that matches image dimensions
MRF=np.ndarray([np.size(imgData,0),np.size(imgData,1),numClass])
MRF[:,:,:]=1

# %% [markdown]
# ##Run Iterative EM process
# Try running with and without the MRF, see how this changes the results, particularly when varying the input file (i.e., brainData vs. noiseData). To do this, comment out the appropriate line in the Expectation code block.
#
# *Remember to reset the parameters above, each time you run the EM algorithm.*

# %%
# Iterative process
while didNotConverge:
    iteration=iteration+1

    # Expectation
    classProbSum[:, :] = 0;
    for classIndex in range(0, numClass):
        gaussPdf = (1/np.sqrt(var[classIndex]*2*np.pi))*np.exp(-0.5* (imgData-mean[classIndex])**2/var[classIndex])
        # classProb[:, :, classIndex] = (gaussPdf + 0.0000001) * MRF[:,:,classIndex] # comment out this line to remove the MRF term
        classProb[:, :, classIndex] = (gaussPdf + 0.0000001) # include this line to remove the MRF term
        classProbSum[:, :] = classProbSum[:, :] + classProb[:, :, classIndex]

    # Normalise posterior
    for classIndex in range(0, numClass):
        classProb[:, :, classIndex] = classProb[:, :, classIndex] / classProbSum[:, :]

    # Maximization
    print("Iteration #" + str(iteration))
    for classIndex in range(0, numClass):
        pik = classProb[:, :, classIndex]
        mean[classIndex] = np.sum(pik*imgData) / np.sum(pik)
        var[classIndex] = np.sum(pik*((imgData - mean[classIndex])**2)) / np.sum(pik)
        # MRF[:,:,classIndex] = np.exp(-beta * Umrf(classProb,classIndex)) # comment out this line to remove the MRF term
        print("Class index " + str(classIndex) + ": mean = " + str(mean[classIndex]) + ", variance = " + str(var[classIndex]))

    # Calculate log likelihood
    oldLogLik = logLik
    logLik = np.sum(np.log(classProbSum))
    diffLogLik = oldLogLik - logLik
    print("Loglikelihood change = " + str(diffLogLik))

    if abs(diffLogLik)<=tolerance:
      didNotConverge=0
      print("Converged after " + str(iteration) + " iterations")

    if iteration>=maxIterations:
        didNotConverge=0
        print("Reached "+ str(maxIterations) + " iterations (the maximum) and did not coverge")
# Out:
# Iteration #1
# Class index 0: mean = [210.28383088], variance = [2066.81903032]
# Class index 1: mean = [113.8723113], variance = [196.24710952]
# Class index 2: mean = [19.48766771], variance = [619.61649955]
# Class index 3: mean = [150.52422693], variance = [235.92729736]
# Class index 4: mean = [157.51533103], variance = [149.36275852]
# Loglikelihood change = -999794014.4128553
# Iteration #2
# Class index 0: mean = [155.69243867], variance = [1360.04274912]
# Class index 1: mean = [111.28998244], variance = [205.10104078]
# Class index 2: mean = [17.82105233], variance = [535.29263533]
# Class index 3: mean = [149.64950975], variance = [218.88434688]
# Class index 4: mean = [157.02573986], variance = [73.34228086]
# Loglikelihood change = -52175.83439657377
# Iteration #3
# Class index 0: mean = [133.08017471], variance = [1425.84585954]
# Class index 1: mean = [110.02968479], variance = [221.00372563]
# Class index 2: mean = [16.05295802], variance = [453.66756597]
# Class index 3: mean = [148.44964112], variance = [227.24943414]
# Class index 4: mean = [158.29025787], variance = [34.42916103]
# Loglikelihood change = -4520.768564118276
# Iteration #4
# Class index 0: mean = [115.9362106], variance = [1733.00687223]
# Class index 1: mean = [110.17272734], variance = [227.95775142]
# Class index 2: mean = [13.6295735], variance = [357.35417843]
# Class index 3: mean = [146.60994586], variance = [243.88168082]
# Class index 4: mean = [159.31502195], variance = [16.69172288]
# Loglikelihood change = -3458.517016649683
# Iteration #5
# Class index 0: mean = [99.29082939], variance = [2072.3822951]
# Class index 1: mean = [111.21103236], variance = [216.05920435]
# Class index 2: mean = [10.71717736], variance = [251.56633728]
# Class index 3: mean = [144.25537031], variance = [260.03241517]
# Class index 4: mean = [159.89065049], variance = [9.77922799]
# Loglikelihood change = -3498.8746863030246
# Iteration #6
# Class index 0: mean = [84.28083561], variance = [2253.0902835]
# Class index 1: mean = [112.36581108], variance = [192.4984036]
# Class index 2: mean = [7.77357218], variance = [146.211187]
# Class index 3: mean = [142.35661781], variance = [274.45245107]
# Class index 4: mean = [160.2010779], variance = [7.01146128]
# Loglikelihood change = -3439.1164145386138
# Iteration #7
# Class index 0: mean = [74.09153647], variance = [2176.41306073]
# Class index 1: mean = [113.25871729], variance = [169.16125987]
# Class index 2: mean = [5.33570027], variance = [63.19076106]
# Class index 3: mean = [141.41847964], variance = [290.5929496]
# Class index 4: mean = [160.36506137], variance = [5.86282115]
# Loglikelihood change = -3513.6288168695464
# Iteration #8
# Class index 0: mean = [68.43184171], variance = [1981.36205584]
# Class index 1: mean = [113.90856932], variance = [150.73966031]
# Class index 2: mean = [3.84328362], variance = [26.08909601]
# Class index 3: mean = [141.3614028], variance = [312.13405769]
# Class index 4: mean = [160.44887722], variance = [5.58584573]
# Loglikelihood change = -4119.254979810212
# Iteration #9
# Class index 0: mean = [64.33371457], variance = [1773.91832839]
# Class index 1: mean = [114.43354611], variance = [138.16890136]
# Class index 2: mean = [3.02964737], variance = [15.99170477]
# Class index 3: mean = [141.84897693], variance = [343.21045532]
# Class index 4: mean = [160.48560673], variance = [6.22152835]
# Loglikelihood change = -3919.611501106003
# Iteration #10
# Class index 0: mean = [60.56024634], variance = [1521.75898428]
# Class index 1: mean = [114.91092551], variance = [133.40527386]
# Class index 2: mean = [2.74200258], variance = [21.72211053]
# Class index 3: mean = [142.58285915], variance = [396.9083532]
# Class index 4: mean = [160.48137687], variance = [8.36861103]
# Loglikelihood change = -2218.3716801669216
# Iteration #11
# Class index 0: mean = [57.00149104], variance = [1146.14036753]
# Class index 1: mean = [115.40342106], variance = [136.87771207]
# Class index 2: mean = [2.89081443], variance = [35.96294302]
# Class index 3: mean = [143.34982332], variance = [497.65563363]
# Class index 4: mean = [160.40460804], variance = [11.91152051]
# Loglikelihood change = 1083.8186417353572
# Iteration #12
# Class index 0: mean = [54.10694571], variance = [873.19502782]
# Class index 1: mean = [115.86756395], variance = [133.82856889]
# Class index 2: mean = [3.10000014], variance = [26.82758741]
# Class index 3: mean = [142.98732399], variance = [594.9553009]
# Class index 4: mean = [160.19262843], variance = [11.23283358]
# Loglikelihood change = 1883.6578564176452
# Iteration #13
# Class index 0: mean = [51.86557356], variance = [721.99827553]
# Class index 1: mean = [116.18578088], variance = [128.45853172]
# Class index 2: mean = [2.91359822], variance = [15.16628981]
# Class index 3: mean = [141.72182777], variance = [660.53944998]
# Class index 4: mean = [160.12239913], variance = [9.28367469]
# Loglikelihood change = -1695.4168626819155
# Iteration #14
# Class index 0: mean = [49.85107858], variance = [639.7843247]
# Class index 1: mean = [116.34507632], variance = [125.42400401]
# Class index 2: mean = [2.63785273], variance = [9.37318239]
# Class index 3: mean = [140.3491799], variance = [709.93298501]
# Class index 4: mean = [160.16457177], variance = [8.01738718]
# Loglikelihood change = -2714.817782461163
# Iteration #15
# Class index 0: mean = [48.06844254], variance = [599.64854393]
# Class index 1: mean = [116.4177238], variance = [124.77062552]
# Class index 2: mean = [2.4513073], variance = [6.61504435]
# Class index 3: mean = [139.08127586], variance = [752.74812787]
# Class index 4: mean = [160.22043464], variance = [7.23467562]
# Loglikelihood change = -2156.449696551499
# Iteration #16
# Class index 0: mean = [46.65246316], variance = [579.04180514]
# Class index 1: mean = [116.47771764], variance = [125.67355316]
# Class index 2: mean = [2.34184152], variance = [5.17527356]
# Class index 3: mean = [137.94949973], variance = [792.31291603]
# Class index 4: mean = [160.26427929], variance = [6.72897584]
# Loglikelihood change = -1491.2674180126924
# Iteration #17
# Class index 0: mean = [45.58019074], variance = [566.415662]
# Class index 1: mean = [116.5621553], variance = [127.42512737]
# Class index 2: mean = [2.27617995], variance = [4.30930892]
# Class index 3: mean = [136.95464813], variance = [829.10242407]
# Class index 4: mean = [160.29489554], variance = [6.38927942]
# Loglikelihood change = -1006.4381279508816
# Iteration #18
# Class index 0: mean = [44.75828298], variance = [557.47165403]
# Class index 1: mean = [116.67653554], variance = [129.62359739]
# Class index 2: mean = [2.23324198], variance = [3.72762347]
# Class index 3: mean = [136.08106896], variance = [863.1600136]
# Class index 4: mean = [160.31563819], variance = [6.15589171]
# Loglikelihood change = -720.4745467619214
# Iteration #19
# Class index 0: mean = [44.10394601], variance = [550.69728931]
# Class index 1: mean = [116.81383634], variance = [132.07741338]
# Class index 2: mean = [2.20253155], variance = [3.30910261]
# Class index 3: mean = [135.30477493], variance = [894.68689501]
# Class index 4: mean = [160.32955318], variance = [5.99373454]
# Loglikelihood change = -549.4781342904316
# Iteration #20
# Class index 0: mean = [43.562524], variance = [545.37946737]
# Class index 1: mean = [116.96555699], variance = [134.70317219]
# Class index 2: mean = [2.17904467], variance = [2.99430001]
# Class index 3: mean = [134.60250081], variance = [924.00770593]
# Class index 4: mean = [160.33877951], variance = [5.88061493]
# Loglikelihood change = -436.86952066616504
# Iteration #21
# Class index 0: mean = [43.10042635], variance = [541.05683689]
# Class index 1: mean = [117.12527081], variance = [137.46791113]
# Class index 2: mean = [2.16027677], variance = [2.74979776]
# Class index 3: mean = [133.95565194], variance = [951.46856619]
# Class index 4: mean = [160.34476161], variance = [5.80181992]
# Loglikelihood change = -356.78006468198146
# Iteration #22
# Class index 0: mean = [42.69669347], variance = [537.40209483]
# Class index 1: mean = [117.28892992], variance = [140.36135535]
# Class index 2: mean = [2.14485451], variance = [2.55503578]
# Class index 3: mean = [133.35051509], variance = [977.3823515]
# Class index 4: mean = [160.34848797], variance = [5.74729644]
# Loglikelihood change = -297.0891971223318
# Iteration #23
# Class index 0: mean = [42.33777099], variance = [534.18575874]
# Class index 1: mean = [117.45428545], variance = [143.38283121]
# Class index 2: mean = [2.13196308], variance = [2.39672044]
# Class index 3: mean = [132.77720352], variance = [1002.0116672]
# Class index 4: mean = [160.35065091], variance = [5.71002591]
# Loglikelihood change = -251.2842632089305
# Iteration #24
# Class index 0: mean = [42.01443557], variance = [531.25481642]
# Class index 1: mean = [117.62026209], variance = [146.53482381]
# Class index 2: mean = [2.12107548], variance = [2.2659364]
# Class index 3: mean = [132.22855969], variance = [1025.56880163]
# Class index 4: mean = [160.35174555], variance = [5.68502778]
# Loglikelihood change = -215.23791665265162
# Iteration #25
# Class index 0: mean = [41.72000071], variance = [528.51404129]
# Class index 1: mean = [117.78648024], variance = [149.81962801]
# Class index 2: mean = [2.11181011], variance = [2.15644393]
# Class index 3: mean = [131.69931054], variance = [1048.22242768]
# Class index 4: mean = [160.35213173], variance = [5.66872036]
# Loglikelihood change = -186.19961356694694
# Converged after 25 iterations

# %% [markdown]
# ###Save segmented images as separate PNG files
# Uncomment the cell below to save to Google drive

# %%
for classIndex in range(0, numClass):
    print("Saving "+"seg"+str(classIndex)+".png")
    save_file(classProb[ : ,: ,classIndex] * 255, "seg"+str(classIndex)+".png")
# Out:
# Saving seg0.png
# Saving seg1.png
# Saving seg2.png
# Saving seg3.png
# Saving seg4.png

# %% [markdown]
# ###Display images
# Take a look at the results. How do they compare to the K-means output? What's the impact of varying K? What difference does the MRF constraint make?

# %%
for seg in range(numClass):
    print('Class number '+str(seg))
    display(Image('seg'+str(seg)+'.png'))
# Out:
# Class number 0
# Class number 1
# Class number 2
# Class number 3
# Class number 4

# %%
ls
# Out:
# IPMI-teaching/  slice_85.png       slice_85_seg1.png  slice_85_seg3.png
# sample_data/    slice_85_seg0.png  slice_85_seg2.png

# %%
display(Image('slice_85_seg0.png'))

# %% [markdown]
# ###Download images
# To get the results you can download the image PNG files to your local machine. Uncomment the code cell below:

# %%
# from google.colab import files
# files.download('seg0.png')

# %% [markdown]
# ##Add anatomical priors to the algorithm
# The priors provide spatial probabilities about the likely tissue class in each pixel. Crucially, these are in the same anatomical space as the input data.

# %% [markdown]
# ###Display image priors

# %%
display(Image(fileLocation+'GM_prior.png'))
display(Image(fileLocation+'WM_prior.png'))
display(Image(fileLocation+'CSF_prior.png'))
display(Image(fileLocation+'NonBrain_prior.png'))

# %% [markdown]
# Read in and convert to arrays

# %%
print("Loading data")
GM_Prior = read_file(fileLocation+'GM_prior.png')
WM_Prior = read_file(fileLocation+'WM_prior.png')
CSF_Prior = read_file(fileLocation+'CSF_prior.png')
Other_Prior = read_file(fileLocation+'NonBrain_prior.png')
# Out:
# Loading data

# %% [markdown]
# ###Edit model parameters to incorporate priors
# Try changing the input data to see how this impacts the results. Note that the number of classes (K) must be the same as the number of different prior maps, so here K must = 4.

# %%
# Select input data
imgData = brainData

# Parameters
didNotConverge = 1
iteration = 0
maxIterations = 20
numClass = 4
beta = 2
logLik = int(-10e8)
oldLogLik = int(-10e8)
tolerance = 200

# Initialise mean and variances
mean = np.random.rand(numClass,1)*256;
var = (np.random.rand(numClass,1)*10)+200;

# Allocate space for the posteriors
classProb = np.ndarray([np.size(imgData,0),np.size(imgData,1),numClass])
classProbSum = np.ndarray([np.size(imgData,0),np.size(imgData,1)])

# Allocate space for the priors
classPrior=np.ndarray([np.size(imgData,0),np.size(imgData,1),4])
classPrior[:, :, 0] = GM_Prior/255
classPrior[:, :, 1] = WM_Prior/255
classPrior[:, :, 2] = CSF_Prior/255
classPrior[:, :, 3] = Other_Prior/255

for classIndex in range(0, numClass):
    pik = classPrior[:, :, classIndex]
    mean[classIndex] = np.sum(pik * imgData) / np.sum(pik)
    var[classIndex] = np.sum(pik * ((imgData - mean[classIndex]) ** 2)) / np.sum(pik)

# Define MRF array to match image dimensions
MRF=np.ndarray([np.size(imgData,0),np.size(imgData,1),numClass])
MRF[:,:,:]=1

# %% [markdown]
# ###Re-run EM process
# This time the class probabilities are multiplied by the probability value from the anatomical prior at each pixel.

# %%
# Conditional to stop process if numClass != 4
if numClass != 4:
    print('no')
    sys.exit("numClass must == 4")

# Iterative process
while didNotConverge:
    iteration=iteration+1

    # Expectation
    classProbSum[:, :] = 0;
    for classIndex in range(0, numClass):
        gaussPdf = (1/np.sqrt(var[classIndex]*2*np.pi))*np.exp(-0.5* (imgData-mean[classIndex])**2/var[classIndex])
        classProb[:, :, classIndex] = (gaussPdf+0.0000001) * classPrior[:, :, classIndex] * MRF[:,:,classIndex]
        classProbSum[:, :] = classProbSum[:, :]+classProb[:, :, classIndex]

    # Normalise posterior
    for classIndex in range(0, numClass):
        classProb[:, :, classIndex] = classProb[:, :, classIndex] /classProbSum[:, :]

    # Maximization
    print("Iteration #"+str(iteration))
    for classIndex in range(0, numClass):
        pik = classProb[:, :, classIndex]
        mean[classIndex] = np.sum(pik*imgData) / np.sum(pik)
        var[classIndex] = np.sum(pik*((imgData - mean[classIndex])**2)) / np.sum(pik)
        MRF[:,:,classIndex] = np.exp(-beta * Umrf(classProb,classIndex))
        print("Class index "+ str(classIndex) + ": mean = "+str(mean[classIndex]) + ", variance = " + str(var[classIndex]))

    # Calculate log likelihood
    oldLogLik = logLik
    logLik = np.sum(np.log(classProbSum))
    diffLogLik = oldLogLik - logLik
    print("Loglikelihood change = " + str(diffLogLik))

    if abs(diffLogLik)<=tolerance:
      didNotConverge=0
      print("Converged after " + str(iteration) + " iterations")

    if iteration>=maxIterations:
        didNotConverge=0
        print("Reached "+ str(maxIterations) + " iterations (the maximum) and did not coverge")
# Out:
# Iteration #1
# Class index 0: mean = [119.08280602], variance = [549.04923411]
# Class index 1: mean = [152.38237367], variance = [211.54946565]
# Class index 2: mean = [92.38972156], variance = [1783.77090033]
# Class index 3: mean = [31.84920567], variance = [2321.1404959]
# Loglikelihood change = -999803440.1502862
# Iteration #2
# Class index 0: mean = [117.12908121], variance = [213.21799132]
# Class index 1: mean = [155.31266215], variance = [104.23148353]
# Class index 2: mean = [74.23591897], variance = [882.59985544]
# Class index 3: mean = [34.21546261], variance = [2530.54007746]
# Loglikelihood change = 47101.72113573656
# Iteration #3
# Class index 0: mean = [117.72201553], variance = [179.3609384]
# Class index 1: mean = [156.30468065], variance = [75.10943858]
# Class index 2: mean = [70.34792359], variance = [572.3106755]
# Class index 3: mean = [34.6323791], variance = [2581.61128375]
# Loglikelihood change = -33300.281819237105
# Iteration #4
# Class index 0: mean = [118.41758083], variance = [167.5741735]
# Class index 1: mean = [156.97970263], variance = [58.36866666]
# Class index 2: mean = [69.43860471], variance = [528.46655414]
# Class index 3: mean = [34.66337433], variance = [2582.60451563]
# Loglikelihood change = -3967.0943096595
# Iteration #5
# Class index 0: mean = [119.07280927], variance = [160.85728894]
# Class index 1: mean = [157.5278695], variance = [45.86860551]
# Class index 2: mean = [68.9810049], variance = [507.2382626]
# Class index 3: mean = [34.68798331], variance = [2583.59073515]
# Loglikelihood change = -887.5462778347137
# Iteration #6
# Class index 0: mean = [119.66444781], variance = [158.1281211]
# Class index 1: mean = [157.97680785], variance = [36.3855315]
# Class index 2: mean = [68.6913919], variance = [491.48374129]
# Class index 3: mean = [34.70263149], variance = [2584.40413126]
# Loglikelihood change = -574.4117101160518
# Iteration #7
# Class index 0: mean = [120.22202142], variance = [158.7931154]
# Class index 1: mean = [158.34491654], variance = [29.63723242]
# Class index 2: mean = [68.53915063], variance = [483.66745487]
# Class index 3: mean = [34.71269497], variance = [2585.10651275]
# Loglikelihood change = -450.2172202930087
# Iteration #8
# Class index 0: mean = [120.73595313], variance = [161.83137279]
# Class index 1: mean = [158.66375022], variance = [24.30217028]
# Class index 2: mean = [68.42599361], variance = [478.09441776]
# Class index 3: mean = [34.71940781], variance = [2585.65940863]
# Loglikelihood change = -338.54092811368173
# Iteration #9
# Class index 0: mean = [121.19567656], variance = [165.89266706]
# Class index 1: mean = [158.91677159], variance = [20.52973204]
# Class index 2: mean = [68.28879108], variance = [471.96656309]
# Class index 3: mean = [34.72371168], variance = [2586.11902222]
# Loglikelihood change = -325.0939249335788
# Iteration #10
# Class index 0: mean = [121.58812861], variance = [170.42485189]
# Class index 1: mean = [159.11035723], variance = [17.95176277]
# Class index 2: mean = [68.15873319], variance = [466.68770652]
# Class index 3: mean = [34.72735212], variance = [2586.48217888]
# Loglikelihood change = -240.8661479105358
# Iteration #11
# Class index 0: mean = [121.91813474], variance = [175.04433489]
# Class index 1: mean = [159.26448381], variance = [16.04797837]
# Class index 2: mean = [68.04931213], variance = [462.63983214]
# Class index 3: mean = [34.72970861], variance = [2586.77983951]
# Loglikelihood change = -166.65741012708168
# Converged after 11 iterations

# %% [markdown]
# Uncomment the cell below to save the files to Google drive

# %%
# for classIndex in range(0, numClass):
#     print("Saving "+"prior_seg"+str(classIndex)+".png")
#     save_file(classProb[ : ,: ,classIndex] * 255, "prior_seg"+str(classIndex)+".png")

# %% [markdown]
# Display the images. How do they compare to the previous versions without anatomical priors?

# %%
display(Image('prior_seg0.png'))
display(Image('prior_seg1.png'))
display(Image('prior_seg2.png'))
display(Image('prior_seg3.png'))

# %% [markdown]
# ---
# #Working with Nifti files
# The following is a brief tutorial on how to load, view and manipulate Nifti (.nii) files in Python. This example takes a slice and run it through the EM procedure using GMMs to segment brain tissue as above. For this example to work well, you need to select an axial slice similar to the anatomical priors.

# %% [markdown]
# ##Define function to read in 3D brain image
# Uses nibabel library to read nifti files

# %%
t1_nii = fileLocation+'T1w_standard.nii.gz'
print(t1_nii)
img = nib.load(t1_nii)
img_array = img.get_fdata() # convert from nifti object to array
# Out:
# ./IPMI-teaching/T1w_standard.nii.gz

# %% [markdown]
# ##Plot image slice

# %%
sliceNumber = 110
plt.imshow(np.rot90(img_array[:, :, sliceNumber]), origin="upper", cmap="gray")
plt.axis('off')
plt.tight_layout()

# %% [markdown]
# Histograms for this slice

# %%
fig = plt.figure(figsize=(12,6))
plt.hist(np.concatenate(img_array[:, :, sliceNumber]), bins=100, facecolor='orangered', edgecolor='black')
plt.xlabel('Intensity')
plt.ylabel('Count')
plt.tight_layout()

# %% [markdown]
# Density plots for multiple slices. Notice that although the plots are generally similar, particularly in that they contain a lot of zeroes (i.e., background pixels), devising a general threshold to distinguish other the intensities in GM, WM and CSF  would not be possible.

# %%
plt.figure(figsize=(12,6))
sns.kdeplot(np.concatenate(img_array[:, :, 8]), color = 'red', bw_method=0.05)
sns.kdeplot(np.concatenate(img_array[:, :, 50]), color = 'blue', bw_method=0.05)
sns.kdeplot(np.concatenate(img_array[:, :, 75]), color = 'green', bw_method=0.05)
sns.kdeplot(np.concatenate(img_array[:, :, 105]), color = 'purple', bw_method=0.05)
sns.kdeplot(np.concatenate(img_array[:, :, 120]), color = 'orange', bw_method=0.05)
plt.tight_layout()

# %% [markdown]
# ###Function for plotting multiple slices

# %%
def plot_slices(slices):
  fig, axes = plt.subplots(1, len(slices), figsize=(16,10))
  for i, slice in enumerate(slices):
    axes[i].imshow(slice.T, cmap="gray", origin="lower")

slice_1 = img_array[:, :, 65]
slice_2 = img_array[:, :, 75]
slice_3 = img_array[:, :, 85]
slice_4 = img_array[:, :, 95]
plot_slices([slice_1, slice_2,slice_3,slice_4])

# %% [markdown]
# ##Save slice as PNG image file

# %%
sliceNumber=85
save_file(img_array[:, :, sliceNumber] * 255, "slice_"+str(sliceNumber)+".png")
display(Image("slice_"+str(sliceNumber)+".png"))

# %% [markdown]
# ## Select a slice and run the segmentation
# Try with and without anatomical priors. Remember this is just in 2D, so be mindful of which slice you select.
# *You'll need to shave off 1 row in the x and y dimensions to fit this brain to the priors. This can be done by indexing the array.*

# %%
img_array2 = img_array[0:181,0:217,1:182]
plt.imshow(img_array2[:, :, sliceNumber], cmap="gray")
slice = img_array2[:,:,sliceNumber]

# %% [markdown]
# Check the dimensions are now correct

# %%
slice.shape
# Out:
# (181, 217)

# %% [markdown]
# **Set parameters**<br>
# Re-run prior to each EM

# %%
# Select input data
imgData = slice

# Parameters
didNotConverge = 1
iteration = 0
maxIterations = 20
numClass = 4
beta = 2
logLik = int(-10e8)
oldLogLik = int(-10e8)
tolerance = 200

# Initialise mean and variances
mean = np.random.rand(numClass,1)*256;
var = (np.random.rand(numClass,1)*10)+200;

# Allocate space for the posteriors
classProb = np.ndarray([np.size(imgData,0),np.size(imgData,1),numClass])
classProbSum = np.ndarray([np.size(imgData,0),np.size(imgData,1)])

# Allocate space for the priors
classPrior=np.ndarray([np.size(imgData,0),np.size(imgData,1),4])
classPrior[:, :, 0] = GM_Prior/255
classPrior[:, :, 1] = WM_Prior/255
classPrior[:, :, 2] = CSF_Prior/255
classPrior[:, :, 3] = Other_Prior/255

for classIndex in range(0, numClass):
    pik = classPrior[:, :, classIndex]
    mean[classIndex] = np.sum(pik * imgData) / np.sum(pik)
    var[classIndex] = np.sum(pik * ((imgData - mean[classIndex]) ** 2)) / np.sum(pik)

# Define MRF array to match image dimensions
MRF=np.ndarray([np.size(imgData,0),np.size(imgData,1),numClass])
MRF[:,:,:]=1

# %% [markdown]
# **Run EM**

# %%
# Iterative process
while didNotConverge:
    iteration=iteration+1

    # Expectation
    classProbSum[:, :] = 0;
    for classIndex in range(0, numClass):
        gaussPdf = (1/np.sqrt(var[classIndex]*2*np.pi))*np.exp(-0.5* (imgData-mean[classIndex])**2/var[classIndex])
        classProb[:, :, classIndex] = (gaussPdf+0.0000001)*classPrior[:, :, classIndex]*MRF[:,:,classIndex]
        classProbSum[:, :] = classProbSum[:, :]+classProb[:, :, classIndex]

    # Normalise posterior
    for classIndex in range(0, numClass):
        classProb[:, :, classIndex] = classProb[:, :, classIndex] /classProbSum[:, :]

    # Maximization
    print("Iteration #"+str(iteration))
    for classIndex in range(0, numClass):
        pik = classProb[:, :, classIndex]
        mean[classIndex] = np.sum(pik*imgData) / np.sum(pik)
        var[classIndex] = np.sum(pik*((imgData - mean[classIndex])**2)) / np.sum(pik)
        MRF[:,:,classIndex] = np.exp(-beta * Umrf(classProb,classIndex))
        print("Class index "+ str(classIndex) + ": mean = "+str(mean[classIndex]) + ", variance = " + str(var[classIndex]))

    # Calculate log likelihood
    oldLogLik = logLik
    logLik = np.sum(np.log(classProbSum))
    diffLogLik = oldLogLik - logLik
    print("Loglikelihood change = " + str(diffLogLik))

    if abs(diffLogLik)<=tolerance:
      didNotConverge=0
      print("Converged after " + str(iteration) + " iterations")

    if iteration>=maxIterations:
        didNotConverge=0
        print("Reached "+ str(maxIterations) + " iterations (the maximum) and did not coverge")
# Out:
# Iteration #1
# Class index 0: mean = [185.55750665], variance = [2620.82964946]
# Class index 1: mean = [236.1530151], variance = [1998.00610812]
# Class index 2: mean = [179.0899803], variance = [4921.29504629]
# Class index 3: mean = [64.55305914], variance = [10051.107051]
# Loglikelihood change = -999774894.5301503
# Iteration #2
# Class index 0: mean = [175.99165076], variance = [1818.08615682]
# Class index 1: mean = [242.69964027], variance = [1688.8664436]
# Class index 2: mean = [165.12820791], variance = [4007.54843693]
# Class index 3: mean = [68.65780298], variance = [10439.99958816]
# Loglikelihood change = 61722.39448586712
# Iteration #3
# Class index 0: mean = [173.88424219], variance = [1641.39773352]
# Class index 1: mean = [243.90337553], variance = [1631.40076782]
# Class index 2: mean = [165.2763731], variance = [4136.83758629]
# Class index 3: mean = [68.86301888], variance = [10438.78475808]
# Loglikelihood change = -36080.96218733268
# Iteration #4
# Class index 0: mean = [172.94237281], variance = [1580.12767737]
# Class index 1: mean = [244.33843641], variance = [1610.82312386]
# Class index 2: mean = [165.87323698], variance = [4158.22705132]
# Class index 3: mean = [68.87133233], variance = [10441.6660073]
# Loglikelihood change = -7409.233795942331
# Iteration #5
# Class index 0: mean = [172.33426953], variance = [1541.30413281]
# Class index 1: mean = [244.69319077], variance = [1592.4225708]
# Class index 2: mean = [166.03892239], variance = [4151.2478681]
# Class index 3: mean = [68.87492952], variance = [10444.22607946]
# Loglikelihood change = -1365.7505659591989
# Iteration #6
# Class index 0: mean = [171.86011224], variance = [1509.51603388]
# Class index 1: mean = [245.00140284], variance = [1575.92019748]
# Class index 2: mean = [166.11581458], variance = [4146.20659109]
# Class index 3: mean = [68.87500648], variance = [10446.9656588]
# Loglikelihood change = -434.75110784202116
# Iteration #7
# Class index 0: mean = [171.45106992], variance = [1479.46825824]
# Class index 1: mean = [245.26699149], variance = [1560.6003651]
# Class index 2: mean = [166.16961325], variance = [4148.45108329]
# Class index 3: mean = [68.87286231], variance = [10448.72297108]
# Loglikelihood change = -255.39709076512372
# Iteration #8
# Class index 0: mean = [171.11644192], variance = [1454.13128124]
# Class index 1: mean = [245.50154671], variance = [1547.4407097]
# Class index 2: mean = [166.25803808], variance = [4150.10076455]
# Class index 3: mean = [68.87180789], variance = [10450.22631603]
# Loglikelihood change = -185.49830150880734
# Converged after 8 iterations

# %% [markdown]
# Save images

# %%
for classIndex in range(0, numClass):
    print("Saving "+"slice_"+str(sliceNumber)+"_seg"+str(classIndex)+".png")
    save_file(classProb[ : ,: ,classIndex] * 255, "slice_"+str(sliceNumber)+"_seg"+str(classIndex)+".png")
# Out:
# Saving slice_85_seg0.png
# Saving slice_85_seg1.png
# Saving slice_85_seg2.png
# Saving slice_85_seg3.png

# %% [markdown]
# Display images

# %%
import glob
for slice_seg in glob.glob('slice_'+str(sliceNumber)+'*seg*.png'):
    print(str(slice_seg))
    display(Image(slice_seg))
# Out:
# slice_85_seg0.png
# slice_85_seg3.png
# slice_85_seg1.png
# slice_85_seg2.png
